# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup as bs
import requests as re

# %%
r = re.get("https://www.etsy.com/c/jewelry?explicit=1&is_star_seller=true&ship_to=US&order=highest_reviews&category_landing_page=true")
soup = bs(r.content)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en-US" xmlns:fb="https://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <script>if (performance && performance.mark) performance.mark("TTP")</script>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="en-US" http-equiv="content-language"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="nosearch" name="pinterest"/>
# <meta content="3:1687138225:5zo15R5S9wg-t2tDXRdVB06FvZXc:d86eaa0446fcd0b1a9975fceb1f7fe23dae67a1a249609119465dd645c400ea8" name="csrf_nonce"/>
# <meta content="3:1687138225:VFwDrDUcezAFTnJmcLQ3K6XiaY2z:6e5113a2a6dba567a1b87170c1a96b720ef116b1baebe7ea7ce6780dc55c6f0c" name="uaid_nonce"/>
# <meta content="89186614300" property="fb:app_id"/>
# <meta content="/ac/sasquatch/css/" name="css_dist_path"/>
# <meta content="202306181687126460" name="dist"/>
# ...
